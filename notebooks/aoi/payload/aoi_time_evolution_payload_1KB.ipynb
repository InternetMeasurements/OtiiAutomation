# %%
from analysis.aoi import load_data, analyse_experiment

# %%
data_1KB = load_data('../../../results/aoi/1KB', n_config=32)
series_1KB = analyse_experiment(data_1KB)
# Out:
# D0-quic-P1KB-Q0
# # Messages                    60
# Observer Time       [ms]      59009.5
# RPI Time            [ms]      59424.0
# RPI Energy          [mJ]      85.73
# Mean gen rate       [msg/s]   1.0 (expected 1)
# Mean receive rate   [msg/s]   1.0
# Peak AoI            [ms]      1126.23
# Mean AoI            [ms]      558.4
# Median AoI          [ms]      558.4 (Above 0.5, Below 0.5)
# D0-quic-P1KB-Q0
# # Messages                    600
# Observer Time       [ms]      59908.27
# RPI Time            [ms]      60345.0
# RPI Energy          [mJ]      100.14
# Mean gen rate       [msg/s]   10.0 (expected 10)
# Mean receive rate   [msg/s]   10.0
# Peak AoI            [ms]      220.82
# Mean AoI            [ms]      94.42
# Median AoI          [ms]      94.13 (Above 0.5, Below 0.5)
# D0-quic-P1KB-Q0
# # Messages                    6000
# Observer Time       [ms]      60029.04
# RPI Time            [ms]      60416.0
# RPI Energy          [mJ]      121.05
# ...
