# %%
from analysis.aoi import load_data, analyse_experiment

# %%
data_256B = load_data('../../../results/aoi/256B', n_config=32)
series_256B = analyse_experiment(data_256B)
# Out:
# D0-quic-P256B-Q0
# # Messages                    60
# Observer Time       [ms]      59022.4
# RPI Time            [ms]      59413.0
# RPI Energy          [mJ]      85.97
# Mean gen rate       [msg/s]   1.0 (expected 1)
# Mean receive rate   [msg/s]   1.0
# Peak AoI            [ms]      1278.86
# Mean AoI            [ms]      585.32
# Median AoI          [ms]      585.33 (Above 0.5, Below 0.5)
# D0-quic-P256B-Q0
# # Messages                    600
# Observer Time       [ms]      59898.09
# RPI Time            [ms]      60344.0
# RPI Energy          [mJ]      98.92
# Mean gen rate       [msg/s]   10.0 (expected 10)
# Mean receive rate   [msg/s]   10.0
# Peak AoI            [ms]      339.17
# Mean AoI            [ms]      97.59
# Median AoI          [ms]      94.79 (Above 0.5, Below 0.5)
# D0-quic-P256B-Q0
# # Messages                    6000
# Observer Time       [ms]      59990.2
# RPI Time            [ms]      60427.0
# RPI Energy          [mJ]      119.96
# ...
