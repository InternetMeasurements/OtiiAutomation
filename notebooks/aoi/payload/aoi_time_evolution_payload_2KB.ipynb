# %%
from analysis.aoi import load_data, analyse_experiment

# %%
data_2KBB = load_data('../../../results/aoi/2KB', n_config=32)
series_2KB = analyse_experiment(data_2KBB)
# Out:
# D0-quic-P2KB-Q0
# # Messages                    60
# Observer Time       [ms]      59012.94
# RPI Time            [ms]      59421.0
# RPI Energy          [mJ]      85.29
# Mean gen rate       [msg/s]   1.0 (expected 1)
# Mean receive rate   [msg/s]   1.0
# Peak AoI            [ms]      1152.56
# Mean AoI            [ms]      556.5
# Median AoI          [ms]      556.5 (Above 0.5, Below 0.5)
# D0-quic-P2KB-Q0
# # Messages                    600
# Observer Time       [ms]      59888.66
# RPI Time            [ms]      60312.0
# RPI Energy          [mJ]      101.22
# Mean gen rate       [msg/s]   10.0 (expected 10)
# Mean receive rate   [msg/s]   10.0
# Peak AoI            [ms]      244.72
# Mean AoI            [ms]      93.76
# Median AoI          [ms]      93.34 (Above 0.5, Below 0.5)
# D0-quic-P2KB-Q0
# # Messages                    6000
# Observer Time       [ms]      59984.54
# RPI Time            [ms]      60466.0
# RPI Energy          [mJ]      132.05
# ...
