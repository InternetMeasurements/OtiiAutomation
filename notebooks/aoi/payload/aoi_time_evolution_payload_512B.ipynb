# %%
from analysis.aoi import load_data, analyse_experiment

# %%
data_512B = load_data('../../../results/aoi/512B', n_config=32)
series_512B = analyse_experiment(data_512B)
# Out:
# D0-quic-P512B-Q0
# # Messages                    60
# Observer Time       [ms]      59018.08
# RPI Time            [ms]      59478.0
# RPI Energy          [mJ]      85.65
# Mean gen rate       [msg/s]   1.0 (expected 1)
# Mean receive rate   [msg/s]   1.0
# Peak AoI            [ms]      1159.78
# Mean AoI            [ms]      559.36
# Median AoI          [ms]      559.36 (Above 0.5, Below 0.5)
# D0-quic-P512B-Q0
# # Messages                    600
# Observer Time       [ms]      59899.67
# RPI Time            [ms]      60303.0
# RPI Energy          [mJ]      101.42
# Mean gen rate       [msg/s]   10.0 (expected 10)
# Mean receive rate   [msg/s]   10.0
# Peak AoI            [ms]      305.41
# Mean AoI            [ms]      93.13
# Median AoI          [ms]      92.59 (Above 0.5, Below 0.5)
# D0-quic-P512B-Q0
# # Messages                    6000
# Observer Time       [ms]      60019.05
# RPI Time            [ms]      60414.0
# RPI Energy          [mJ]      118.6
# ...
