# %%
from analysis.aoi import load_data, analyse_experiment, pareto

# %%
data_256B = load_data('../../../results/aoi/256B', n_config=32)
series_256B = analyse_experiment(data_256B, draw_plots=False)

data_512B = load_data('../../../results/aoi/512B', n_config=32)
series_512B = analyse_experiment(data_512B, draw_plots=False)

data_1KB = load_data('../../../results/aoi/1KB', n_config=32)
series_1KB = analyse_experiment(data_1KB, draw_plots=False)

data_2KB = load_data('../../../results/aoi/2KB', n_config=32)
series_2KB = analyse_experiment(data_2KB, draw_plots=False)

# %% [markdown]
# # 256B

# %%
pareto(series_256B, metric='median', dump='../../../results/aoi/aoi_256B.json')

# %% [markdown]
# # 512B

# %%
pareto(series_512B, metric='median', dump='../../../results/aoi/aoi_512B.json')

# %% [markdown]
# # 1KB

# %%
pareto(series_1KB, metric='median', dump='../../../results/aoi/aoi_1KB.json')

# %% [markdown]
# # 2KB

# %%
pareto(series_2KB, metric='median', dump='../../../results/aoi/aoi_2KB.json')
