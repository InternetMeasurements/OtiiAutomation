# %%
from analysis.aoi import load_data, analyse_experiment, pareto

# %%
data = load_data('../results/aoi/2024-02-22_12-01-50')

# %%
series = analyse_experiment(data)
# Out:
# D80-quic-P128B-Q1024
# # Messages                    60
# Observer Time       [ms]      59027.15
# RPI Time            [ms]      59952.0
# RPI Energy          [mJ]      107.46
# Mean gen rate       [msg/s]   1.0 (expected 1)
# Mean receive rate   [msg/s]   1.0
# Peak AoI            [ms]      1289.77
# Mean AoI            [ms]      708.46
# Median AoI          [ms]      738.47 (Above 0.47, Below 0.53)
# D80-quic-P128B-Q1024
# # Messages                    600
# Observer Time       [ms]      59958.32
# RPI Time            [ms]      60895.0
# RPI Energy          [mJ]      119.89
# Mean gen rate       [msg/s]   10.0 (expected 10)
# Mean receive rate   [msg/s]   9.99
# Peak AoI            [ms]      592.1
# Mean AoI            [ms]      363.01
# Median AoI          [ms]      361.27 (Above 0.504, Below 0.496)
# D80-quic-P128B-Q1024
# # Messages                    6000
# Observer Time       [ms]      60165.16
# RPI Time            [ms]      60893.0
# RPI Energy          [mJ]      140.03
# ...

# %%
pareto([series], metric='median')
