# %%
from analysis.aoi import fast_aoi

# %% [markdown]
# ## QUIC Q1

# %%
fast_aoi('../results/observer_quic_q1.json')
# Out:
# # Messages                    300000
# Observer Time       [ms]      158558.79
# Mean receive rate   [msg/s]   1892.04
# Peak AoI            [ms]      882.75
# Mean AoI            [ms]      53.61
# Median AoI          [ms]      39.1 (Above 0.5, Below 0.5)
# Queue time          [ms]      0.599

# %% [markdown]
# ## TLS Q1

# %% [markdown]
# ### With delay

# %%
fast_aoi('../results/observer_tls_q1.json')
# Out:
# # Messages                    300000
# Observer Time       [ms]      77238.57
# Mean receive rate   [msg/s]   3884.06
# Peak AoI            [ms]      368.4
# Mean AoI            [ms]      48.26
# Median AoI          [ms]      43.14 (Above 0.5, Below 0.5)
# Queue time          [ms]      0.318

# %% [markdown]
# ### No Delay

# %%
fast_aoi('../results/observer_tls_q1_no_delay.json')
# Out:
# # Messages                    300000
# Observer Time       [ms]      118261.47
# Mean receive rate   [msg/s]   2536.74
# Peak AoI            [ms]      384.32
# Mean AoI            [ms]      47.21
# Median AoI          [ms]      39.95 (Above 0.5, Below 0.5)
# Queue time          [ms]      0.458

# %% [markdown]
# ## Quic Q0

# %%
fast_aoi('../results/observer_quic_q0.json')
# Out:
# # Messages                    105280
# Observer Time       [ms]      60021.41
# Mean receive rate   [msg/s]   1754.02
# Peak AoI            [ms]      144.33
# Mean AoI            [ms]      40.23
# Median AoI          [ms]      37.25 (Above 0.5, Below 0.5)
# Queue time          [ms]      0.105

# %% [markdown]
# ## Tls Q0

# %% [markdown]
# ### With delay

# %%
fast_aoi('../results/observer_tls_q0.json')
# Out:
# # Messages                    105524
# Observer Time       [ms]      60064.63
# Mean receive rate   [msg/s]   1756.82
# Peak AoI            [ms]      151.06
# Mean AoI            [ms]      45.54
# Median AoI          [ms]      42.2 (Above 0.5, Below 0.5)
# Queue time          [ms]      0.134

# %% [markdown]
# ### No Delay

# %%
fast_aoi('../results/observer_tls_q0_no_delay.json')
# Out:
# # Messages                    101073
# Observer Time       [ms]      60016.72
# Mean receive rate   [msg/s]   1684.06
# Peak AoI            [ms]      179.94
# Mean AoI            [ms]      40.14
# Median AoI          [ms]      36.59 (Above 0.5, Below 0.5)
# Queue time          [ms]      0.2
