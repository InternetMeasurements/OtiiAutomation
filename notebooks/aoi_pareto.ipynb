# %%
from analysis.aoi import load_data, analyse_experiment, pareto

# %%
# %matplotlib inline

# %% [markdown]
# ## No additional delay

# %%
data_128B_Q1024 = load_data('../results/aoi/128B_D0/Q1024', n_config=22)
series_128B_Q1024 = analyse_experiment(data_128B_Q1024, draw_plots=False)

data_128B_Q16 = load_data('../results/aoi/128B_D0/Q16', n_config=22)
series_128B_Q16 = analyse_experiment(data_128B_Q16, draw_plots=False)

data_128B_Q1 = load_data('../results/aoi/128B_D0/Q1', n_config=22)
series_128B_Q1 = analyse_experiment(data_128B_Q1, draw_plots=False)

data_128B_Q0 = load_data('../results/aoi/128B_D0/Q0', n_config=22)
series_128B_Q0 = analyse_experiment(data_128B_Q0, draw_plots=False)

# %%
# %matplotlib inline
pareto(series_128B_Q0, series_128B_Q1, series_128B_Q16, series_128B_Q1024, metric='mean')

del data_128B_Q1024, series_128B_Q1024, data_128B_Q16, series_128B_Q16, data_128B_Q1, series_128B_Q1, data_128B_Q0, series_128B_Q0

# %% [markdown]
# ## Delay 20

# %%
data_128B_D20 = load_data('../results/aoi/128B_D20', n_config=88)
series_128B_D20 = analyse_experiment(data_128B_D20, draw_plots=False)

# %%
pareto(series_128B_D20, metric='mean')
del data_128B_D20, series_128B_D20

# %% [markdown]
# ## Delay 40

# %%
data_128B_D40 = load_data('../results/aoi/128B_D40', n_config=88)
series_128B_D40 = analyse_experiment(data_128B_D40, draw_plots=False)

# %%
pareto(series_128B_D40, metric='mean')
del data_128B_D40, series_128B_D40

# %% [markdown]
# ## Delay 60

# %%
data_128B_D60 = load_data('../results/aoi/128B_D60', n_config=88)
series_128B_D60 = analyse_experiment(data_128B_D60, draw_plots=False)

# %%
pareto(series_128B_D60, metric='mean')
del data_128B_D60, series_128B_D60

# %% [markdown]
# ## Delay 80

# %%
data_128B_D80 = load_data('../results/aoi/128B_D80', n_config=88)
series_128B_D80 = analyse_experiment(data_128B_D80, draw_plots=False)

# %%
pareto(series_128B_D80, metric='mean')
del data_128B_D80, series_128B_D80
