# %%
from analysis.aoi import load_data, analyse_experiment, pareto

# %%
AOI_PATHS = {
    '128B_Q1024':'../results/aoi/128B_Q1024',
    '128B_Q16': '../results/aoi/128B_Q16',
    '128B_Q1': '../results/aoi/128B_Q1',
    '128B_Q0': '../results/aoi/128B_Q0',
}

# %% [markdown]
# ## Q1024

# %%
data_128B_Q1024 = load_data(AOI_PATHS['128B_Q1024'])
series_128B_Q1024 = analyse_experiment(data_128B_Q1024, draw_plots=False)

# %% [markdown]
# ## Q16

# %%
data_128B_Q16 = load_data(AOI_PATHS['128B_Q16'])
series_128B_Q16 = analyse_experiment(data_128B_Q16, draw_plots=False)

# %% [markdown]
# ## Q1

# %%
data_128B_Q1 = load_data(AOI_PATHS['128B_Q1'])
series_128B_Q1 = analyse_experiment(data_128B_Q1, draw_plots=False)

# %% [markdown]
# ## Q0

# %%
data_128B_Q0 = load_data(AOI_PATHS['128B_Q0'])
series_128B_Q0 = analyse_experiment(data_128B_Q0, draw_plots=False)

# %% [markdown]
# ## Pareto

# %%
pareto([series_128B_Q1024, series_128B_Q16, series_128B_Q1, series_128B_Q0], metric='median')
