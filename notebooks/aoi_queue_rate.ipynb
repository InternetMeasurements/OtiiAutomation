# %%
from analysis.aoi import fast_aoi

# %%
fast_aoi('../results/wireshark/quic_4000_Q1024.json')
# Out:
# # Messages                    240000
# Observer Time       [ms]      60009.8
# Mean generation rate[msg/s]   3999.94
# Mean receive rate   [msg/s]   3999.33
# Peak AoI            [ms]      439.63
# Mean AoI            [ms]      77.84
# Median AoI          [ms]      72.04 (Above 0.5, Below 0.5)

# %%
fast_aoi('../results/wireshark/quic_4000_Q16.json')
# Out:
# # Messages                    240000
# Observer Time       [ms]      60017.05
# Mean generation rate[msg/s]   4000.01
# Mean receive rate   [msg/s]   3998.85
# Peak AoI            [ms]      458.14
# Mean AoI            [ms]      104.16
# Median AoI          [ms]      96.32 (Above 0.5, Below 0.5)

# %%
fast_aoi('../results/wireshark/quic_4000_Q1.json')
# Out:
# # Messages                    240000
# Observer Time       [ms]      119960.58
# Mean generation rate[msg/s]   2001.08
# Mean receive rate   [msg/s]   2000.65
# Peak AoI            [ms]      505.83
# Mean AoI            [ms]      112.05
# Median AoI          [ms]      106.19 (Above 0.5, Below 0.5)

# %%
fast_aoi('../results/wireshark/quic_4000_Q0.json')
# Out:
# # Messages                    103968
# Observer Time       [ms]      60010.97
# Mean generation rate[msg/s]   1732.81
# Mean receive rate   [msg/s]   1732.47
# Peak AoI            [ms]      492.8
# Mean AoI            [ms]      131.58
# Median AoI          [ms]      126.04 (Above 0.5, Below 0.5)
